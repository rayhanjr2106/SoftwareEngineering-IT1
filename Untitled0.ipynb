# %%
a = 2
hewan = "Gajah"
c = True
d = False
e = 2.0
f = [] #List
g = {} #Dictionary
h= () #Tuple

# %%
hewan = "gajah"
print(hewan)
print("{}".format(hewan)) #works good with integer print("Nama hewan adalah : " + str(a))
print("Angka : {} Hewan : {} Nomor : {}".format(a, hewan, 23))
# Out:
# gajah
# gajah
# Angka : 2 Hewan : gajah Nomor : 23

# %%
Nama_Siswa = ["Aufa", "Rizal", "Juven", "Rhesa"]
nama = ["Rhesa"] * 4
# for i in range(1, 3):
  # print(Nama_Siswa[i])
# Nama_Siswa[0:2] #Nama_Siswa[-2]
# nama[0:5]
nama.append(2)
# nama[-3:]
Nama_Siswa[0:3]
# Out:
# ['Aufa', 'Rizal', 'Juven']

# %%
a = ()
